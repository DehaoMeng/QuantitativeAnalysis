# %% [markdown]
# # Numpy案例

# %%
#NGSIM 项目收集一段时间内道路上所有车辆的轨迹、速度、加速度等驾驶数据。
#美国高速公路车辆驾驶行为轨迹数据集,包含了US101的txt和全部的csv文件,需要自取,可作标定车辆驾驶行为参数,作驾驶模拟分析统计等用途。

# %%
import numpy as np
import pandas as pd
rawdata=pd.read_excel('C:/Users/QIEZI/Desktop/NGSIM简易数据集.xlsx')
print(rawdata)
#本段代码可以直击复制粘贴，但是read_excel()中的数据集绝对地址需要改成大家存储文件的地址。
# Out:
#     Vehicle_ID\n（车辆编号）   Frame_ID\n（时间点）   Local_X\n（车辆左前角x轴坐标）  \
# 0                    6               161                 27.290
# 1                    1               160                 52.451
# 2                    2               179                 38.636
# 3                    2               179                 17.241
# 4                    7               175                 15.964
# 5                    6               173                 27.979
# 6                    3               163                  6.363
# 7                    5               163                  4.948
# 8                    4               165                  1.833
# 9                    2               163                 11.639
# 10                   2               169                 17.508
# 11                   3               174                  6.403
# 12                   6               180                 64.580
# 13                   5               166                  4.948
# ...

# %%
data=np.array(rawdata,dtype='int32')
data
#本段代码可以直击复制粘贴，作用为将DataFrame数据转换为ndarray类型的数据

# %%
#问题1.找出时间点（原数据Frame_ID列）在170之后的车辆

# %%
#问题2.筛选出车辆速度超过40英尺/秒的车的Frame_ID

# %%
#问题3.向data内添加一列，该列的数值均为1，数据类型为int32

# %%
#问题4.先筛选出车辆编号（原数据Vehicle_ID列）为2的行，保存在变量data2中，
#然后根据Frame_ID列按照升序排列data2。然后根据Frame_ID列和Lane_ID列,
#判断车辆有没有换道（即后一个时间点对应的Lane_ID是否和前一个时间点的Lane_ID相同），
#没换道标记为0，换道标记为1。
